# %% [markdown]
# ## CARGAR LOS DATOS

# %% [markdown]
# Importamos las librerias numpy (operaciones matemáticas), pandas (dataframes), seaborn y matplotlib(visualización).

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Leemos el archivo .csv original y creamos una copia.

# %%
dataset = pd.read_csv("../data/GBvideos_cc50_202101.csv")
datasetcopia = dataset

# %% [markdown]
# ## INSPECCIONAR LOS DATOS

# %% [markdown]
# Exploramos el dataframe, con la instrucción *info()*

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38916 entries, 0 to 38915
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                38916 non-null  object
#  1   trending_date           38916 non-null  object
#  2   title                   38916 non-null  object
#  3   channel_title           38916 non-null  object
#  4   category_id             38916 non-null  int64
#  5   publish_time            38916 non-null  object
#  6   tags                    38916 non-null  object
#  7   views                   38916 non-null  int64
#  8   likes                   38916 non-null  int64
#  9   dislikes                38916 non-null  int64
#  10  comment_count           38916 non-null  int64
#  11  thumbnail_link          38916 non-null  object
#  12  comments_disabled       38916 non-null  bool
#  13  ratings_disabled        38916 non-null  bool
# ...

# %% [markdown]
# Dado esta salida, sabemos que existen 38916 entradas (filas), con 19 variables (columnas)

# %% [markdown]
# Además. inspeccionamos con la función *describe()*

# %%
dataset.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count  \
# count  38916.000000  3.891600e+04  3.891600e+04  3.891600e+04   3.891600e+04
# mean      16.827937  5.911944e+06  1.345196e+05  7.612560e+03   1.308835e+04
# std        7.752728  1.900121e+07  3.499893e+05  5.095683e+04   5.066740e+04
# min        1.000000  8.510000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       10.000000  2.515272e+05  5.897000e+03  2.000000e+02   6.790000e+02
# 50%       20.000000  9.818890e+05  2.518250e+04  8.210000e+02   2.478000e+03
# 75%       24.000000  3.683628e+06  1.140892e+05  3.357500e+03   9.241500e+03
# max       43.000000  4.245389e+08  5.613827e+06  1.944971e+06   1.626501e+06
#
#                 lat           lon
# count  38916.000000  38916.000000
# mean      53.383720     -2.379078
# std        2.043531      2.103878
# min       50.133722     -7.333284
# 25%       51.499995     -3.529950
# 50%       53.200020     -2.180007
# ...

# %% [markdown]
# Ahora, veamos las entradas con la instrucción *head()*

# %%
dataset.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id              publish_time  \
# 0                  John Lewis           26  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club           17  2017-11-13T02:30:38.000Z
# 4            Cute Girl Videos           25  2017-11-13T01:45:13.000Z
#
# ...

# %% [markdown]
# ## PRE-PROCESAR LOS DATOS

# %% [markdown]
# ### VALORES FALTANTES

# %% [markdown]
# Vamos a inspeccionar cuantos NAs existen en cada columna

# %%
datasetcopia.isna().sum()
# Out:
# video_id                    0
# trending_date               0
# title                       0
# channel_title               0
# category_id                 0
# publish_time                0
# tags                        0
# views                       0
# likes                       0
# dislikes                    0
# comment_count               0
# thumbnail_link              0
# comments_disabled           0
# ratings_disabled            0
# video_error_or_removed      0
# description               612
# state                       0
# lat                         0
# lon                         0
# geometry                    0
# dtype: int64

# %% [markdown]
# Podemos notar que solo, el description tiene 612 valore NAs. Entonces, podemos asignar su valor con 'No description'.

# %%
datasetcopia['description'].fillna('No description', inplace=True)

# %% [markdown]
# Revisamos la cantidad de NA's para confirmar.

# %%
datasetcopia.isna().sum()
# Out:
# video_id                  0
# trending_date             0
# title                     0
# channel_title             0
# category_id               0
# publish_time              0
# tags                      0
# views                     0
# likes                     0
# dislikes                  0
# comment_count             0
# thumbnail_link            0
# comments_disabled         0
# ratings_disabled          0
# video_error_or_removed    0
# description               0
# state                     0
# lat                       0
# lon                       0
# geometry                  0
# dtype: int64

# %% [markdown]
# ### OUTLIERS

# %% [markdown]
# Creamos una función para arreglar los outliers

# %%
def arreglarOutliers(data):
    outliers = data.quantile([0.05,0.95])
    n = len(data)
    outliers = list(outliers)
    mean = data.mean()
    median = data.median()
    
    for element in range(n):
        if int(data[element]) < int(outliers[0]):
            data.loc[element]= mean
        elif int(data[element]) > int(outliers[1]):
            data.loc[element]= median

    return data

# %% [markdown]
# ### TRENDING_DATE, PUBLISH_TIME

# %%
datasetcopia['trending_date'] = pd.to_datetime(datasetcopia['trending_date'], format='%y.%d.%m')
datasetcopia['publish_time'] = pd.to_datetime(datasetcopia['publish_time'])

# %% [markdown]
# ### ARREGLAR OUTLIERS DE LA COLUMNA FECHA

# %%
def arreglarOutliersfecha(data):
    outliers = data.quantile([0.02,0.98])
    n = len(data)
    outliers = list(outliers)
    for element in range(n):
        if data[element] > outliers[1] or data[element]<outliers[0]:
            data[element] = np.nan

# %% [markdown]
# ### CREAR COLUMNA PARA DESCRIPCIÓN DE LA CATEGORIA

# %%
dfCategory = pd.read_json('GB_category_id.json')

# %%
dfCategory.head()
# Out:
#                                 kind  \
# 0  youtube#videoCategoryListResponse
# 1  youtube#videoCategoryListResponse
# 2  youtube#videoCategoryListResponse
# 3  youtube#videoCategoryListResponse
# 4  youtube#videoCategoryListResponse
#
#                                                 etag  \
# 0  "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
# 1  "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
# 2  "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
# 3  "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
# 4  "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
#
#                                                items
# 0  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 1  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 2  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 3  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 4  {'kind': 'youtube#videoCategory', 'etag': '"m2...

# %%
dfCategory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   kind    32 non-null     object
#  1   etag    32 non-null     object
#  2   items   32 non-null     object
# dtypes: object(3)
# memory usage: 896.0+ bytes

# %%
items = dfCategory['items']

# %%
category = dict()
for i in range(len(dfCategory)):
    category[items[i]['id']] = items[i]['snippet']['title']

# %%
datasetcopia['category_description'] = [ category[str(i)] for i in datasetcopia['category_id']]
datasetcopia['category_description']
# Out:
# 0          Howto & Style
# 1          Entertainment
# 2                  Music
# 3                 Sports
# 4        News & Politics
#               ...
# 38911              Music
# 38912              Music
# 38913              Music
# 38914      Entertainment
# 38915              Music
# Name: category_description, Length: 38916, dtype: object

# %% [markdown]
# ### EXPORT CSV

# %%
datasetcopia.to_csv('../data/GB_dataset_preprocessed.csv', index=False)

# %%
data = pd.read_csv('../data/GB_dataset_preprocessed.csv')
data
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU    2017-11-14
# 1      3s1rvMFUweQ    2017-11-14
# 2      n1WpP7iowLc    2017-11-14
# 3      PUTEiSjKwJU    2017-11-14
# 4      rHwDegptbI4    2017-11-14
# ...            ...           ...
# 38911  l884wKofd54    2018-06-14
# 38912  IP8k2xkhOdI    2018-06-14
# 38913  Il-an3K9pjg    2018-06-14
# 38914  -DRsfNObKIQ    2018-06-14
# 38915  4YFo4bdMO8Q    2018-06-14
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %% [markdown]
# ## Nuevo data frame con las frecuencias

# %%
data1 = data.set_index(['trending_date', 'video_id'])
data1.head()
# Out:
#                                                                        title  \
# trending_date video_id
# 2017-11-14    Jw1Y-zhQURU      John Lewis Christmas Ad 2017 - #MozTheMonster
#               3s1rvMFUweQ          Taylor Swift: …Ready for It? (Live) - SNL
#               n1WpP7iowLc         Eminem - Walk On Water (Audio) ft. Beyoncé
#               PUTEiSjKwJU  Goals from Salford City vs Class of 92 and Fri...
#               rHwDegptbI4  Dashcam captures truck's near miss with child ...
#
#                                         channel_title  category_id  \
# trending_date video_id
# 2017-11-14    Jw1Y-zhQURU                  John Lewis           26
#               3s1rvMFUweQ         Saturday Night Live           24
#               n1WpP7iowLc                  EminemVEVO           10
#               PUTEiSjKwJU  Salford City Football Club           17
#               rHwDegptbI4            Cute Girl Videos           25
#
# ...

# %%
# Nuevo dataframe con Video Level Stats
video_level = data1.groupby(level=1).last()
video_level['freq'] = data1['title'].groupby(level=1).count()
video_level.sort_values(by=['views'], ascending=False, inplace=True)

video_level.head(10)
# Out:
#                                                          title  \
# video_id
# _I_D_8Z4sJE  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...
# 9jI-z9QN6g8  Te Bote Remix - Casper, Nio García, Darell, Ni...
# kLpH1nSLJSs               Bad Bunny - Amorfoda | Video Oficial
# wfWkmURBNv8           Ozuna x Romeo Santos - El Farsante Remix
# VYOjWnS4cMY  Childish Gambino - This Is America (Official V...
# xpVfcZ0ZcFM                                 Drake - God’s Plan
# ffxKSjUwKdU               Ariana Grande - No Tears Left To Cry
# zEf423kYfqk  Becky G, Natti Natasha - Sin Pijama (Official ...
# FlsCjmMhFmw  YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# sGIm0-dQd8M                Dura - Daddy Yankee (Video Oficial)
#
#                    channel_title  category_id               publish_time  \
# video_id
# _I_D_8Z4sJE           NickyJamTV           10  2018-03-02 05:00:19+00:00
# 9jI-z9QN6g8        Flow La Movie           10  2018-04-11 22:00:00+00:00
# ...

# %% [markdown]
# ## Preguntas

# %% [markdown]
# ### 1. ¿Qué categorías de videos son las de mayor tendencia

# %%
pregunta1 = video_level.copy()
pregunta1 = video_level.groupby(['category_description']).sum()
pregunta1.sort_values(by=['freq'], ascending=False, inplace=True)
pregunta1

sns.set(font_scale=1.5, rc={'figure.figsize':(11.7,8.27)})
tmp = pregunta1.freq
_ = sns.barplot(y=tmp.index, x=tmp)

# %%
pregunta1[['freq']]
# Out:
#                         freq
# category_description
# Music                  13771
# Entertainment           9116
# People & Blogs          2905
# Film & Animation        2580
# Howto & Style           1939
# Sports                  1906
# Comedy                  1835
# Gaming                  1779
# News & Politics         1225
# Pets & Animals           534
# Science & Technology     518
# Education                457
# Autos & Vehicles         144
# Travel & Events           96
# Nonprofits & Activism     90
# Shows                     21

# %% [markdown]
# ### 2. ¿Qué categorias de videos son los que más gustan? ¿Y las que menos gustan?

# %%
pregunta2 = video_level.copy()
pregunta2 = video_level.groupby(['category_description']).sum()
pregunta2.sort_values(by=['likes'], ascending=False, inplace=True)

sns.set(font_scale=1.5, rc={'figure.figsize':(11.7,8.27)})
tmp = pregunta2.views
_ = sns.barplot(y=tmp.index,x=tmp)

# %%
pregunta2[['views']]
# Out:
#                              views
# category_description
# Music                  11497452062
# Entertainment           2231506534
# Comedy                   392685082
# People & Blogs           356606081
# Film & Animation         483077803
# Gaming                   141603268
# Sports                   226954817
# Howto & Style             89539350
# Nonprofits & Activism     30551744
# News & Politics           98727625
# Science & Technology      85668222
# Education                 29628525
# Pets & Animals            36918849
# Autos & Vehicles          20406847
# Travel & Events           10717623
# Shows                      1709880

# %% [markdown]
# ### 3. ¿Qué categorías de videos tienen la mejor proporción (ratio) de “Me gusta” / “No me gusta”?

# %%
temp3 = video_level.copy()

temp3.dislikes = [1 if i==0 else i for i in temp3.dislikes]
temp3['ratio'] = temp3['likes']/temp3['dislikes']
max_ratio_like_dislike = temp3['ratio'].max() #Ver cual es la mejor proporción

ans3 = temp3[temp3['ratio']==max_ratio_like_dislike]
print(f'Número de videos con el mismo ratio:\t{len(ans3)}')
print(f'Las categorías con mejor proporción de “Me gusta” / “No me gusta” son:\n{ans3.category_description.unique()}')

#visualización
g=sns.barplot(x='ratio', y='category_description',data=temp3)

plt.rcParams["figure.figsize"] = (20,20)
plt.xticks(rotation=90)
plt.show()
# Out:
# Número de videos con el mismo ratio:	1
# Las categorías con mejor proporción de “Me gusta” / “No me gusta” son:
# ['Music']

# %% [markdown]
# ### 4. ¿Qué categorías de videos tienen la mejor proporción (ratio) de “Vistas” / “Comentarios”?

# %%
import math

temp4 = video_level.copy()
temp4.comment_count = [1 if i==0 else i for i in temp4.comment_count]
temp4['ratio'] = temp4['views']/temp4['comment_count']
# print([i for i in ratio_view_comment if math.isclose(i, 1, rel_tol=0.96)])
temp4['near1'] = [math.isclose(i, 1, rel_tol=0.96) for i in temp4['ratio']]
# near_ratio_view_comment = [(i==closest5)>0 for i in ratio_view_comment]
print(f"Número de videos con mismo ratio:\t{sum(temp4['near1'])}")
# Talvez algo sobre los comentarios deshabilitados
ans4 = temp4[temp4['near1']==True]
# No hay problema
# print(f"Verificamos que el maximo ratio no se de {ans_vid[ans4_vid.comments_disabled==False]}")
print(f'Las categorías con mejor proporción de “Vistas” / “Comentarios” son:\n{ans4[ans4.comments_disabled==False].category_description.unique()}')

#visualización
g=sns.barplot(x='ratio', y='category_description',data=temp4)

plt.rcParams["figure.figsize"] = (20,20)
plt.xticks(rotation=90)
plt.show()
# Out:
# Número de videos con mismo ratio:	4
# Las categorías con mejor proporción de “Vistas” / “Comentarios” son:
# ['Comedy' 'Howto & Style' 'Entertainment' 'People & Blogs']

# %% [markdown]
# ### 5. ¿Cómo ha cambiado el volumen de los videos en tendencia a lo largo del tiempo?

# %%
pregunta3 = data.copy()
pregunta3 = pregunta3.groupby('trending_date').count()
pregunta3['cantidad'] = pregunta3['title']

_ = pregunta3[['cantidad']].plot(title="Distribución de volumen de videos a lo largo del tiempo")
plt.xticks(rotation=25)
# Out:
# (array([-25.,   0.,  25.,  50.,  75., 100., 125., 150., 175., 200., 225.]),
#  [Text(-25.0, 0, '2018-05-21'),
#   Text(0.0, 0, '2017-11-14'),
#   Text(25.0, 0, '2017-12-09'),
#   Text(50.0, 0, '2018-01-03'),
#   Text(75.0, 0, '2018-01-30'),
#   Text(100.0, 0, '2018-02-24'),
#   Text(125.0, 0, '2018-03-21'),
#   Text(150.0, 0, '2018-04-21'),
#   Text(175.0, 0, '2018-05-16'),
#   Text(200.0, 0, '2018-06-10'),
#   Text(225.0, 0, '')])

# %%
pregunta3[['cantidad']]
# Out:
#                cantidad
# trending_date
# 2017-11-14          200
# 2017-11-15          199
# 2017-11-16          199
# 2017-11-17          200
# 2017-11-18          200
# ...                 ...
# 2018-06-10          168
# 2018-06-11          166
# 2018-06-12          171
# 2018-06-13          170
# 2018-06-14          165
#
# [205 rows x 1 columns]

# %% [markdown]
# ### 6. ¿Qué Canales de YouTube son tendencia más frecuentemente? ¿Y cuáles con menos frecuencia?

# %%
tendency_count = video_level['channel_title'].value_counts()
tendency_count_max = tendency_count[:5]
g = sns.barplot(tendency_count_max.index,tendency_count_max.values)
#print(tendency_count_max.values)
i=0
for val in tendency_count_max.values:
    g.text(i,5,val,color='black', ha="center")
    i+=1
g.set_title('5 canales mas frecuentes en tendencias')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\aldav\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#tendency_count = video_level['channel_title'].value_counts()
tendency_count_min = tendency_count[1606:]
g = sns.barplot(tendency_count_min.index,tendency_count_min.values)
#print(tendency_count_max.values)
i=0
for val in tendency_count_min.values:
    g.text(i,1,val,color='black', ha="center")
    i+=1
g.set_title('5 canales menos frecuentes en tendencias')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\aldav\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\aldav\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 50689 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\Users\aldav\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# ...

# %% [markdown]
# ### 7. ¿En qué Estados se presenta el mayor número de “Vistas”, “Me gusta” y “No me gusta”?

# %%
data7 = video_level.sort_values(['state']).copy()
#type(data7)
data7 = data7.groupby(['state'])['views'].sum().reset_index()
data7.head()
# Out:
#                           state      views
# 0                      Aberdeen  220407613
# 1  Bath And North East Somerset  388126753
# 2                       Belfast  131570640
# 3                   Bournemouth  224467607
# 4             Brighton And Hove  221634058

# %%
data7 = data7.sort_values(['views'])
#data7.sort_values(by=['state'], ascending=False, inplace=True)
g=sns.barplot(x='views',y='state',data=data7)
g.set_title('reproducciones por estado')
plt.rcParams["figure.figsize"] = (20,20)

plt.show()

# %%
data7 = video_level.sort_values(['state']).copy()
#type(data7)
data7 = data7.groupby(['state'])['likes'].sum().reset_index()
data7.head()
# Out:
#                           state    likes
# 0                      Aberdeen  5120336
# 1  Bath And North East Somerset  7811611
# 2                       Belfast  3568972
# 3                   Bournemouth  4262683
# 4             Brighton And Hove  5238176

# %%
data7 = data7.sort_values(['likes'])
g=sns.barplot(x='likes',y='state',data=data7)
g.set_title('likes por estado')
plt.rcParams["figure.figsize"] = (20,20)

plt.show()

# %%
data7 = video_level.sort_values(['state']).copy()
#type(data7)
data7 = data7.groupby(['state'])['dislikes'].sum().reset_index()
data7.head()
# Out:
#                           state  dislikes
# 0                      Aberdeen    202753
# 1  Bath And North East Somerset    439694
# 2                       Belfast    171106
# 3                   Bournemouth    143396
# 4             Brighton And Hove    121341

# %%
data7 = data7.sort_values(['dislikes'])
g=sns.barplot(x='dislikes',y='state',data=data7)
g.set_title('dislikes por estado')
plt.rcParams["figure.figsize"] = (20,20)

plt.show()

# %% [markdown]
# ### 8. ¿Es factible predecir el número de “Vistas” o “Me gusta” o “No me gusta”?

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X=video_level[['likes','dislikes']]
y=video_level['views']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.30, 
                                                    random_state=101)

lm = LinearRegression()
lm.fit(X_train,y_train)
slope = lm.coef_

coef_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coeficiente'])
coef_df
# Out:
#           Coeficiente
# likes       49.522458
# dislikes    37.793865

# %%
X=video_level[['views','dislikes']]
y=video_level['likes']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, 
                                                    random_state=101)
lm = LinearRegression()
lm.fit(X_train,y_train)
slope = lm.coef_

coef_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coeficiente'])
coef_df
# Out:
#           Coeficiente
# views        0.011259
# dislikes     1.439863

# %%
X=video_level[['views','likes']]
y=video_level['dislikes']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.30, 
                                                    random_state=101)

lm = LinearRegression()
lm.fit(X_train,y_train)
slope = lm.coef_

coef_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coeficiente'])
coef_df
# Out:
#        Coeficiente
# views     0.000319
# likes     0.047611

# %% [markdown]
# ### 9. ¿Los videos en tendencia son los que mayor cantidad de comentarios positivos reciben?

# %%
temp9 = video_level.copy()
above_mean = temp9['likes']>temp9['likes'].mean()
below_mean = [not i for i in above_mean]

print('Porcentaje de videos cuyos "Me gusta" superan el promedio:\n',\
    sum(temp9[above_mean].freq)/(sum(temp9[below_mean].freq)+sum(temp9[above_mean].freq))*100, '%')

#visualización
plt.rcParams["figure.figsize"] = (5,5)
plt.pie([sum(temp9[above_mean].freq), sum(temp9[below_mean].freq)],
    labels=['Encima del promedio', 'Debajo del promedio'])
plt.show()
# Out:
# Porcentaje de videos cuyos "Me gusta" superan el promedio:
#  29.30157261794635 %
